# %%
import pandas as pd 
df = pd.read_csv('../data_processed/load_europe.csv' , parse_dates=["timestamp"])

# %%
print(df.head())
print(df.timestamp.min(), df.timestamp.max())
print(df.country.unique())
print(df.isna().sum())
# Out:
#                   timestamp country  load_MW
# 0 2014-12-31 23:00:00+00:00      DE      NaN
# 1 2015-01-01 00:00:00+00:00      DE  41151.0
# 2 2015-01-01 01:00:00+00:00      DE  40135.0
# 3 2015-01-01 02:00:00+00:00      DE  39106.0
# 4 2015-01-01 03:00:00+00:00      DE  38765.0
# 2014-12-31 23:00:00+00:00 2020-09-30 23:00:00+00:00
# ['DE' 'HU' 'RO']
# timestamp      0
# country        0
# load_MW      127
# dtype: int64

# %%
df = pd.read_csv("../data_processed/merged_raw.csv", parse_dates=["timestamp"])
print(df.head())
print(df.isna().sum())
print(df.country.unique())
# Out:
#             timestamp country  load_MW  temp_C  humidity_pct  cloud_pct
# 0 2014-12-31 23:00:00      DE      NaN     4.0            96         87
# 1 2015-01-01 00:00:00      DE  41151.0     3.8            96         71
# 2 2015-01-01 01:00:00      DE  40135.0     3.6            95         69
# 3 2015-01-01 02:00:00      DE  39106.0     3.3            94         95
# 4 2015-01-01 03:00:00      DE  38765.0     3.0            94         82
# timestamp         0
# country           0
# load_MW         127
# temp_C            0
# humidity_pct      0
# cloud_pct         0
# dtype: int64
# ['DE' 'HU' 'RO']
